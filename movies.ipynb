# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/csv/movies.csv")

# %%
data.describe()
# Out:
#                srno          year        rating          time
# count  49590.000000  49590.000000  10814.000000  45836.000000
# mean   24795.500000   2002.303428      3.451248   2628.445436
# std    14315.544261     12.534555      0.495601   1604.646265
# min        1.000000   1913.000000      1.400000     52.000000
# 25%    12398.250000   1999.000000      3.100000   1356.000000
# 50%    24795.500000   2007.000000      3.500000   2563.000000
# 75%    37192.750000   2010.000000      3.800000   2877.000000
# max    49590.000000   2014.000000      4.500000  28813.000000

# %%
data.head()
# Out:
#    srno                 movie  year  rating    time
# 0     1  The Nightmare Before  1993     3.9  4568.0
# 1     2             The Mummy  1932     3.5  4388.0
# 2     3  Orphans of the Storm  1921     3.2  9062.0
# 3     4  The Object of Beauty  1991     2.8  6150.0
# 4     5            Night Tide  1963     2.8  5126.0

# %%
data.head(5)
# Out:
#    srno                 movie  year  rating    time
# 0     1  The Nightmare Before  1993     3.9  4568.0
# 1     2             The Mummy  1932     3.5  4388.0
# 2     3  Orphans of the Storm  1921     3.2  9062.0
# 3     4  The Object of Beauty  1991     2.8  6150.0
# 4     5            Night Tide  1963     2.8  5126.0

# %%
data2=data.loc[(data.time>5000)&(data.year==2000)]
data2
# Out:
#         srno                       movie  year  rating    time
# 409      410                     Believe  2000     3.3  5767.0
# 416      417  The Prophecy 3: The Ascent  2000     3.4  5048.0
# 430      431                    Scream 3  2000     3.2  7013.0
# 432      433                  Holy Smoke  2000     3.0  6855.0
# 437      438         Requiem for a Dream  2000     3.9  6087.0
# ...      ...                         ...   ...     ...     ...
# 32557  32558               Shaded Places  2000     2.9  5350.0
# 36229  36230           The Three Stooges  2000     3.7  5256.0
# 37333  37334       Les Miserables: Pt. 2  2000     NaN  5170.0
# 37336  37337       Les Miserables: Pt. 1  2000     NaN  5194.0
# 39493  39494          The Prophet's Game  2000     3.2  6486.0
#
# [137 rows x 5 columns]

# %%
data.head(100)
# Out:
#     srno                           movie  year  rating    time
# 0      1            The Nightmare Before  1993     3.9  4568.0
# 1      2                       The Mummy  1932     3.5  4388.0
# 2      3            Orphans of the Storm  1921     3.2  9062.0
# 3      4            The Object of Beauty  1991     2.8  6150.0
# 4      5                      Night Tide  1963     2.8  5126.0
# ..   ...                             ...   ...     ...     ...
# 95    96                      The Hunted  1995     3.4  6605.0
# 96    97          The Great Waldo Pepper  1975     3.5  6467.0
# 97    98  Godzilla: King of the Monsters  1956     3.5  4828.0
# 98    99  Highlander 2: Renegade Version  1991     3.1  6585.0
# 99   100                       High Noon  1952     3.9  5087.0
#
# [100 rows x 5 columns]

# %%
data.head(50)
# Out:
#     srno                                          movie  year  rating     time
# 0      1                           The Nightmare Before  1993     3.9   4568.0
# 1      2                                      The Mummy  1932     3.5   4388.0
# 2      3                           Orphans of the Storm  1921     3.2   9062.0
# 3      4                           The Object of Beauty  1991     2.8   6150.0
# 4      5                                     Night Tide  1963     2.8   5126.0
# 5      6                            One Magic Christmas  1985     3.8   5333.0
# 6      7                               Muriel's Wedding  1994     3.5   6323.0
# 7      8                                  Mother's Boys  1994     3.4   5733.0
# 8      9                    Nosferatu: Original Version  1929     3.5   5651.0
# 9     10                                   Nick of Time  1995     3.4   5333.0
# 10    11                                Broken Blossoms  1919     3.3   5367.0
# ...

# %%
data.tail(50)
# Out:
#         srno                                              movie  year  rating  \
# 49540  49541  Life With Boys: Season 1: This Time the Proble...  2011     NaN
# 49541  49542  Life With Boys: Season 1: In the Principal's O...  2011     NaN
# 49542  49543                                 El Fuente: 5994 MP  2013     3.5
# 49543  49544    Life With Boys: Season 1: Monkey Talk with Boys  2011     NaN
# 49544  49545                                   El Fuente: 50 MP  2013     3.3
# 49545  49546                                  Bo Burnham: what.  2013     4.1
# 49546  49547  Life With Boys: Season 1: A Perfect Life with ...  2011     NaN
# 49547  49548      Life With Boys: Season 1: Wrestling with Boys  2011     NaN
# 49548  49549                           Life With Boys: Season 1  2011     4.1
# 49549  49550                                   El Fuente: 30 MP  2013     3.3
# 49550  49551                                 El Fuente: 2997 MP  2013     3.2
# ...

# %%
data1=data.loc[(data.rating==4)&(data.year<=2010)&(data.year>2000)]
data1
# Out:
#         srno                             movie  year  rating     time
# 816      817                    Dil Chahta Hai  2001     4.0  11110.0
# 865      866                   Black Hawk Down  2001     4.0   8660.0
# 920      921                  We Were Soldiers  2002     4.0   8309.0
# 1329    1330                Farscape: Season 3  2001     4.0      NaN
# 1362    1363        The Forsyte Saga: Series 1  2002     4.0      NaN
# ...      ...                               ...   ...     ...      ...
# 47718  47719                     Killer Whales  2010     4.0   2620.0
# 47793  47794      King Tut Unwrapped: Season 1  2010     4.0      NaN
# 48066  48067  Police Women of Dallas: Season 1  2010     4.0      NaN
# 48784  48785                King Tut Unwrapped  2010     4.0      NaN
# 49028  49029            Police Women of Dallas  2010     4.0      NaN
#
# [278 rows x 5 columns]

# %%
data=data.sort_values('time')
data
# Out:
#         srno                              movie  year  rating  time
# 40150  40151                      Trailer: Pain  2012     3.6  52.0
# 41081  41082               Trailer: Get to Work  2012     3.3  55.0
# 41082  41083             Trailer: Give and Take  2012     3.3  66.0
# 43166  43167                   Trailer: Emperor  2013     3.1  67.0
# 43330  43331               Trailer: Blood Angel  2013     4.2  69.0
# ...      ...                                ...   ...     ...   ...
# 49556  49557                       Shinobi Girl  2012     2.0   NaN
# 49561  49562  My Hope America with Billy Graham  2013     3.9   NaN
# 49565  49566  My Hope America with Billy Graham  2013     3.9   NaN
# 49588  49589                    Kate Plus Ei8ht  2010     2.7   NaN
# 49589  49590          Kate Plus Ei8ht: Season 1  2010     2.7   NaN
#
# [49590 rows x 5 columns]

# %%
data=data.sort_values('rating')
data
# Out:
#         srno                                              movie  year  rating  \
# 40826  40827                                             Lagegi  2007     1.4
# 42115  42116                                Sun Yaar Chill Maar  2007     1.4
# 42160  42161                                Sun Yaar Chill Maar  2007     1.4
# 40934  40935                                             Lagegi  2007     1.4
# 41083  41084                           Meri Toh Lag Gayi Naukri  2011     1.5
# ...      ...                                                ...   ...     ...
# 36004  36005  WWE: The Ladder Match 2: Crash &#38; Burn: Vol. 3  2011     NaN
# 32093  32094    WWE: Hulk Hogan: The Ultimate Anthology: Part 2  2006     NaN
# 44551  44552  WWE: The Best of Raw &#38; SmackDown 2012: Vol. 3  2012     NaN
# 32092  32093    WWE: Hulk Hogan: The Ultimate Anthology: Part 3  2006     NaN
# 35767  35768              WWE: Best of King of the Ring: Vol. 3  2011     NaN
#
#           time
# 40826      NaN
# ...

# %%
data.isna().sum()
# Out:
# srno          0
# movie         0
# year          0
# rating    38776
# time       3754
# dtype: int64

# %%
data1=data.fillna(data.median())
data1
# Out:
#         srno                                              movie  year  rating  \
# 0          1                               The Nightmare Before  1993     3.9
# 1          2                                          The Mummy  1932     3.5
# 2          3                               Orphans of the Storm  1921     3.2
# 3          4                               The Object of Beauty  1991     2.8
# 4          5                                         Night Tide  1963     2.8
# ...      ...                                                ...   ...     ...
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     3.5
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     3.5
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#          time
# 0      4568.0
# ...

# %%
data.shape
# Out:
# (49590, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49590 entries, 0 to 49589
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   srno    49590 non-null  int64
#  1   movie   49590 non-null  object
#  2   year    49590 non-null  int64
#  3   rating  10814 non-null  float64
#  4   time    45836 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.9+ MB

# %%
data1=data.groupby(['year']).count()

# %%
data1
# Out:
#       srno  movie  rating  time
# year
# 1913     3      3       3     3
# 1914    20     20       5    18
# 1915     1      1       1     1
# 1916     1      1       1     1
# 1918     1      1       1     1
# ...    ...    ...     ...   ...
# 2010  5107   5107    1102  4671
# 2011  5511   5511    1346  4992
# 2012  4339   4339    1130  3978
# 2013   981    981     345   901
# 2014     1      1       1     1
#
# [101 rows x 4 columns]

# %%
data1.to_csv('movie.csv')

# %%
data1.plot()
# Out:
# <Axes: xlabel='year'>
