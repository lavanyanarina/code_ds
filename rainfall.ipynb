# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/csv/rainfall in india 1901-2015.csv")

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
list(data)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
data["SUBDIVISION"].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data=data.groupby(['SUBDIVISION']).count()

# %%
data
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data3=data.loc([data,SUBDIVISION == "ARUNACHAL PRADESH"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[255], line 1
# ----> 1 data3=data.loc([data,SUBDIVISION == "ARUNACHAL PRADESH"])
#
# NameError: name 'SUBDIVISION' is not defined

# %%
data.isna().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# Jan-Feb    0
# Mar-May    0
# Jun-Sep    0
# Oct-Dec    0
# dtype: int64

# %%
data=data.loc[(data.YEAR <2010)]

# %%
data
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data1=data.drop(['YEAR','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANNUAL'],axis=1)

# %%
data1
# Out:
#                                     Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS               110      107      107      107
# ARUNACHAL PRADESH                        96       95       95       94
# ASSAM & MEGHALAYA                       115      115      115      115
# BIHAR                                   115      115      115      115
# CHHATTISGARH                            115      115      115      115
# COASTAL ANDHRA PRADESH                  115      115      115      115
# COASTAL KARNATAKA                       114      115      115      115
# EAST MADHYA PRADESH                     115      115      115      115
# EAST RAJASTHAN                          115      115      115      115
# EAST UTTAR PRADESH                      115      115      115      115
# GANGETIC WEST BENGAL                    115      115      115      115
# GUJARAT REGION                          115      115      115      115
# ...

# %%
data1['ANNUAL_RAIN'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)

# %%
data1
# Out:
#                                     Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS               110      107      107      107
# ARUNACHAL PRADESH                        96       95       95       94
# ASSAM & MEGHALAYA                       115      115      115      115
# BIHAR                                   115      115      115      115
# CHHATTISGARH                            115      115      115      115
# COASTAL ANDHRA PRADESH                  115      115      115      115
# COASTAL KARNATAKA                       114      115      115      115
# EAST MADHYA PRADESH                     115      115      115      115
# EAST RAJASTHAN                          115      115      115      115
# EAST UTTAR PRADESH                      115      115      115      115
# GANGETIC WEST BENGAL                    115      115      115      115
# GUJARAT REGION                          115      115      115      115
# ...

# %%
data1['JAN'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['FEB'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['MAR'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['APR'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['MAY'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['JUNE'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['JULY'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['AUG'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['SEP'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['OCT'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['NOV'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)
data1['DEC'] = data.apply([lambda row: row.JAN+row.FEB],axis=1)

# %%
data1
# Out:
#                                     Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS               110      107      107      107
# ARUNACHAL PRADESH                        96       95       95       94
# ASSAM & MEGHALAYA                       115      115      115      115
# BIHAR                                   115      115      115      115
# CHHATTISGARH                            115      115      115      115
# COASTAL ANDHRA PRADESH                  115      115      115      115
# COASTAL KARNATAKA                       114      115      115      115
# EAST MADHYA PRADESH                     115      115      115      115
# EAST RAJASTHAN                          115      115      115      115
# EAST UTTAR PRADESH                      115      115      115      115
# GANGETIC WEST BENGAL                    115      115      115      115
# GUJARAT REGION                          115      115      115      115
# ...

# %%
cor=data1.corr()
cor
# Out:
#               Jan-Feb   Mar-May   Jun-Sep   Oct-Dec  ANNUAL_RAIN       JAN  \
# Jan-Feb      1.000000  0.989273  0.988203  0.985370     0.996615  0.996615
# Mar-May      0.989273  1.000000  0.998940  0.996081     0.986271  0.986271
# Jun-Sep      0.988203  0.998940  1.000000  0.996960     0.985346  0.985346
# Oct-Dec      0.985370  0.996081  0.996960  1.000000     0.976851  0.976851
# ANNUAL_RAIN  0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# JAN          0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# FEB          0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# MAR          0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# APR          0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# MAY          0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# JUNE         0.996615  0.986271  0.985346  0.976851     1.000000  1.000000
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
data2['SWM'] = data1.apply([lambda row: row.JUNE+row.JULY+row.AUG+row.SEP],axis=1)

# %%
data2
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...
