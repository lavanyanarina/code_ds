# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/csv/fiat500.csv")

# %%
data.head()
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
list(data)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
data['model']=data['model'].map({'longue':1,'pop':2,'sport':3})
data
# Out:
#         ID  model  engine_power  age_in_days      km  previous_owners  \
# 0        1    NaN            51          882   25000                1
# 1        2    2.0            51         1186   32500                1
# 2        3    3.0            74         4658  142228                1
# 3        4    NaN            51         2739  160000                1
# 4        5    2.0            73         3074  106880                1
# ...    ...    ...           ...          ...     ...              ...
# 1533  1534    3.0            51         3712  115280                1
# 1534  1535    NaN            74         3835  112000                1
# 1535  1536    2.0            51         2223   60457                1
# 1536  1537    NaN            51         2557   80750                1
# 1537  1538    2.0            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
cor=data.corr()
cor
# Out:
#                        ID     model  engine_power  age_in_days        km  \
# ID               1.000000 -0.034208     -0.034059    -0.060753 -0.006537
# model           -0.034208  1.000000      0.247432     0.413986  0.390822
# engine_power    -0.034059  0.247432      1.000000     0.319190  0.285495
# age_in_days     -0.060753  0.413986      0.319190     1.000000  0.833890
# km              -0.006537  0.390822      0.285495     0.833890  1.000000
# previous_owners  0.007803  0.142875     -0.005030     0.075775  0.097539
# lat             -0.058207  0.026766      0.005721     0.062982  0.035519
# lon              0.058941 -0.018251     -0.005032    -0.042667  0.004839
# price            0.028516 -0.343564     -0.277235    -0.893328 -0.859373
#
#                  previous_owners       lat       lon     price
# ID                      0.007803 -0.058207  0.058941  0.028516
# model                   0.142875  0.026766 -0.018251 -0.343564
# ...

# %%
  data.plot()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=5,cmap='bwr')
# Out:
# <Axes: >
